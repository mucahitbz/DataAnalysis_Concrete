# %%
import pandas as pd
import numpy as np
restoran = pd.read_csv("BalajiFastFoodSales.csv")
print(restoran.shape)
restoran.head()
# Out:
# (1000, 10)
#    order_id        date        item_name  item_type  item_price  quantity  \
# 0         1  07-03-2022         Aalopuri   Fastfood          20        13
# 1         2   8/23/2022          Vadapav   Fastfood          20        15
# 2         3  11/20/2022          Vadapav   Fastfood          20         1
# 3         4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4         5  10-02-2022  Sugarcane juice  Beverages          25         8
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                 260              NaN         Mr.        Night
# 1                 300             Cash         Mr.    Afternoon
# 2                  20             Cash         Mr.    Afternoon
# 3                 150           Online         Mr.        Night
# 4                 200           Online         Mr.      Evening

# %%
restoran.isna().sum()
# Out:
# order_id                0
# date                    0
# item_name               0
# item_type               0
# item_price              0
# quantity                0
# transaction_amount      0
# transaction_type      107
# received_by             0
# time_of_sale            0
# dtype: int64

# %%
restoran.transaction_type.value_counts()
# Out:
# transaction_type
# Cash      476
# Online    417
# Name: count, dtype: int64

# %%
eksiksiz=restoran.fillna({'transaction_type': 'Other'})
eksiksiz
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 0           1  07-03-2022         Aalopuri   Fastfood          20        13
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4           5  10-02-2022  Sugarcane juice  Beverages          25         8
# ..        ...         ...              ...        ...         ...       ...
# 995       996   3/19/2023          Frankie   Fastfood          50        10
# 996       997   9/20/2022         Sandwich   Fastfood          60         7
# 997       998   1/26/2023         Sandwich   Fastfood          60        13
# 998       999   8/27/2022         Panipuri   Fastfood          20         5
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
# ...

# %%
restoran
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 0           1  07-03-2022         Aalopuri   Fastfood          20        13
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4           5  10-02-2022  Sugarcane juice  Beverages          25         8
# ..        ...         ...              ...        ...         ...       ...
# 995       996   3/19/2023          Frankie   Fastfood          50        10
# 996       997   9/20/2022         Sandwich   Fastfood          60         7
# 997       998   1/26/2023         Sandwich   Fastfood          60        13
# 998       999   8/27/2022         Panipuri   Fastfood          20         5
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
# ...

# %%
eksiksiz
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 0           1  07-03-2022         Aalopuri   Fastfood          20        13
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4           5  10-02-2022  Sugarcane juice  Beverages          25         8
# ..        ...         ...              ...        ...         ...       ...
# 995       996   3/19/2023          Frankie   Fastfood          50        10
# 996       997   9/20/2022         Sandwich   Fastfood          60         7
# 997       998   1/26/2023         Sandwich   Fastfood          60        13
# 998       999   8/27/2022         Panipuri   Fastfood          20         5
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
# ...

# %%
eksiksiz.isna().sum()
# Out:
# order_id              0
# date                  0
# item_name             0
# item_type             0
# item_price            0
# quantity              0
# transaction_amount    0
# transaction_type      0
# received_by           0
# time_of_sale          0
# dtype: int64

# %%
eksiksiz.plot.box()
# Out:
# <Axes: >

# %%
toplam_tutar = eksiksiz['transaction_amount']
#toplam_tutar

# %%
toplam_tutar = eksiksiz['transaction_amount']
toplam_tutar.describe()
# Out:
# count    1000.000000
# mean      275.230000
# std       204.402979
# min        20.000000
# 25%       120.000000
# 50%       240.000000
# 75%       360.000000
# max       900.000000
# Name: transaction_amount, dtype: float64

# %%
Q1 = toplam_tutar.quantile (0.25)
Q3 = toplam_tutar.quantile (0.75)
IQR = Q3 - Q1
print ("Q1: {}, Q3: {}, IQR = {}".format(Q1,Q3,IQR))
# Out:
# Q1: 120.0, Q3: 360.0, IQR = 240.0

# %%
alt_sinir = Q1 - (IQR*1.5) 
ust_sinir = Q3 + (IQR*1.5)
print (alt_sinir)
print (ust_sinir)
# Out:
# -240.0
# 720.0

# %%
toplam_tutar[toplam_tutar< alt_sinir].count()
# Out:
# 0

# %%
toplam_tutar[toplam_tutar> ust_sinir].count()
# Out:
# 44

# %%
toplam_tutar[toplam_tutar > ust_sinir]  = ust_sinir 
toplam_tutar[toplam_tutar < alt_sinir]  = alt_sinir
# Out:
# C:\Users\korkm\AppData\Local\Temp\ipykernel_19488\56849352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toplam_tutar[toplam_tutar > ust_sinir]  = ust_sinir
# C:\Users\korkm\AppData\Local\Temp\ipykernel_19488\56849352.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toplam_tutar[toplam_tutar < alt_sinir]  = alt_sinir

# %%
toplam_tutar.describe()
# Out:
# count    1000.000000
# mean      270.640000
# std       192.436671
# min        20.000000
# 25%       120.000000
# 50%       240.000000
# 75%       360.000000
# max       720.000000
# Name: transaction_amount, dtype: float64

# %%
eksiksiz.plot.box()
# Out:
# <Axes: >

# %%
restoran.plot.box()
# Out:
# <Axes: >

# %%
toplam_tutar.plot.box()
# Out:
# <Axes: >

# %%
eksiksiz.describe()
# Out:
#           order_id   item_price     quantity  transaction_amount
# count  1000.000000  1000.000000  1000.000000         1000.000000
# mean    500.500000    33.315000     8.162000          270.640000
# std     288.819436    14.921744     4.413075          192.436671
# min       1.000000    20.000000     1.000000           20.000000
# 25%     250.750000    20.000000     4.000000          120.000000
# 50%     500.500000    25.000000     8.000000          240.000000
# 75%     750.250000    50.000000    12.000000          360.000000
# max    1000.000000    60.000000    15.000000          720.000000

# %%
print(eksiksiz[['item_price','quantity','transaction_amount']].var())
# Out:
# item_price              222.658433
# quantity                 19.475231
# transaction_amount    37031.872272
# dtype: float64

# %%
eksiksiz.transaction_amount.value_counts()
# Out:
# transaction_amount
# 300    57
# 200    56
# 720    51
# 60     47
# 40     46
# 100    44
# 120    44
# 240    42
# 280    41
# 260    34
# 350    33
# 160    32
# 20     31
# 80     31
# 400    28
# 600    28
# 180    27
# 220    22
# 140    22
# 250    19
# 420    17
# 650    17
# 360    17
# 480    17
# 25     16
# 500    14
# 520    14
# 175    14
# 150    13
# 320    12
# 325    12
# 50     11
# 440    10
# 125    10
# 450    10
# 375     9
# 225     9
# 560     9
# 660     7
# 75      7
# 540     7
# 550     5
# 275     5
# 700     3
# Name: count, dtype: int64

# %%
#total_sales = eksiksiz.groupby(['time_of_sale', 'item_name']).sum().loc[:,['transaction_amount']]
total_sales=eksiksiz.groupby(['time_of_sale', 'item_name'])['transaction_amount'].sum().unstack()
total_sales
# Out:
# item_name     Aalopuri  Cold coffee  Frankie  Panipuri  Sandwich  \
# time_of_sale
# Afternoon         4520        13480    11840      4600      8940
# Evening           2720         9400    11970      4820     12000
# Midnight          4460         8120     9750      5560     11820
# Morning           4300        11480    10110      4660     12840
# Night             4880        11960    13500      4880     15960
#
# item_name     Sugarcane juice  Vadapav
# time_of_sale
# Afternoon                8125     3880
# Evening                  7075     3980
# Midnight                 5925     4700
# Morning                  5150     3900
# Night                    5675     3660

# %%
total_sales = eksiksiz.groupby(['time_of_sale', 'item_name'])['transaction_amount'].sum()
total_sales
# Out:
# time_of_sale  item_name
# Afternoon     Aalopuri            4520
#               Cold coffee        13480
#               Frankie            11840
#               Panipuri            4600
#               Sandwich            8940
#               Sugarcane juice     8125
#               Vadapav             3880
# Evening       Aalopuri            2720
#               Cold coffee         9400
#               Frankie            11970
#               Panipuri            4820
#               Sandwich           12000
#               Sugarcane juice     7075
#               Vadapav             3980
# Midnight      Aalopuri            4460
#               Cold coffee         8120
#               Frankie             9750
#               Panipuri            5560
#               Sandwich           11820
#               Sugarcane juice     5925
#               Vadapav             4700
# Morning       Aalopuri            4300
#               Cold coffee        11480
# ...

# %%
#total_sales = eksiksiz.groupby(['time_of_sale', 'item_name']).sum().loc[:,['transaction_amount']]
#total_sales=eksiksiz.groupby(['time_of_sale', 'item_name'])['transaction_amount'].sum().unstack()

total_sales = eksiksiz.groupby(['time_of_sale']).sum().loc[:,['transaction_amount','quantity']]
total_sales
# Out:
#               transaction_amount  quantity
# time_of_sale
# Afternoon                  56345      1714
# Evening                    52355      1540
# Midnight                   50725      1575
# Morning                    53730      1574
# Night                      62075      1759

# %%
total_salesa = eksiksiz.groupby(['item_name']).sum().loc[:,['transaction_amount','quantity']]
total_salesa
# Out:
#                  transaction_amount  quantity
# item_name
# Aalopuri                      20880      1044
# Cold coffee                   54440      1361
# Frankie                       57500      1150
# Panipuri                      24520      1226
# Sandwich                      65820      1097
# Sugarcane juice               31950      1278
# Vadapav                       20120      1006

# %%
#eksiksiz.groupby('item_name').sum().loc[:,['transaction_amount','quantity']].sum()
total_sales = eksiksiz.groupby(['time_of_sale']).sum().loc[:,['transaction_amount','quantity']]
total_sales
# Out:
#               transaction_amount  quantity
# time_of_sale
# Afternoon                  56345      1714
# Evening                    52355      1540
# Midnight                   50725      1575
# Morning                    53730      1574
# Night                      62075      1759

# %%
eksiksiz.groupby('time_of_sale').sum().loc[:,['transaction_amount']]
# Out:
#               transaction_amount
# time_of_sale
# Afternoon                  56345
# Evening                    52355
# Midnight                   50725
# Morning                    53730
# Night                      62075

# %%
eksiksiz['zamli_urun'] = eksiksiz['item_price'] + 5  
eksiksiz['zamli_toplam'] = eksiksiz['zamli_urun'] * eksiksiz['quantity'] 
eksiksiz
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 0           1  07-03-2022         Aalopuri   Fastfood          20        13
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4           5  10-02-2022  Sugarcane juice  Beverages          25         8
# ..        ...         ...              ...        ...         ...       ...
# 995       996   3/19/2023          Frankie   Fastfood          50        10
# 996       997   9/20/2022         Sandwich   Fastfood          60         7
# 997       998   1/26/2023         Sandwich   Fastfood          60        13
# 998       999   8/27/2022         Panipuri   Fastfood          20         5
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
# ...

# %%
t2  = eksiksiz.groupby(['item_name']).sum().loc[:,['transaction_amount','zamli_toplam']]
t2
# Out:
#                  transaction_amount  zamli_toplam
# item_name
# Aalopuri                      20880         26100
# Cold coffee                   54440         61245
# Frankie                       57170         63250
# Panipuri                      24520         30650
# Sandwich                      61560         71305
# Sugarcane juice               31950         38340
# Vadapav                       20120         25150

# %%
t2.loc['Toplam'] = t2.sum()
t2
# Out:
#                  transaction_amount  zamli_toplam
# item_name
# Aalopuri                      20880         26100
# Cold coffee                   54440         61245
# Frankie                       57170         63250
# Panipuri                      24520         30650
# Sandwich                      61560         71305
# Sugarcane juice               31950         38340
# Vadapav                       20120         25150
# Toplam                       270640        316040

# %%
t2['kar_orani'] = (t2['zamli_toplam'] - t2['transaction_amount']) / t2['transaction_amount'] * 100
t2
# Out:
#                  transaction_amount  zamli_toplam  kar_orani
# item_name
# Aalopuri                      20880         26100  25.000000
# Cold coffee                   54440         61245  12.500000
# Frankie                       57170         63250  10.634948
# Panipuri                      24520         30650  25.000000
# Sandwich                      61560         71305  15.830084
# Sugarcane juice               31950         38340  20.000000
# Vadapav                       20120         25150  25.000000
# Toplam                       270640        316040  16.775052

# %%
t4  = eksiksiz.groupby(['item_name']).sum().loc[:,['transaction_amount','zamli_toplam']]
t4.loc['Toplam'] = t4.sum()
t4['kar_orani'] = (t4['zamli_toplam'] - t4['transaction_amount']) / t4['transaction_amount'] * 100
t4
# Out:
#                  transaction_amount  zamli_toplam  kar_orani
# item_name
# Aalopuri                      20880         26100  25.000000
# Cold coffee                   54440         61245  12.500000
# Frankie                       57170         63250  10.634948
# Panipuri                      24520         30650  25.000000
# Sandwich                      61560         71305  15.830084
# Sugarcane juice               31950         38340  20.000000
# Vadapav                       20120         25150  25.000000
# Toplam                       270640        316040  16.775052

# %%
tablo= eksiksiz.groupby(['item_name']).sum().loc[:,['transaction_amount','zamli_toplam']]
tablo.loc['Toplam'] = tablo.sum()
tablo['kar_orani'] = (tablo['zamli_toplam'] - tablo['transaction_amount']) / tablo['transaction_amount'] * 100
tablo
# Out:
#                  transaction_amount  zamli_toplam  kar_orani
# item_name
# Aalopuri                      20880         26100  25.000000
# Cold coffee                   54440         61245  12.500000
# Frankie                       57170         63250  10.634948
# Panipuri                      24520         30650  25.000000
# Sandwich                      61560         71305  15.830084
# Sugarcane juice               31950         38340  20.000000
# Vadapav                       20120         25150  25.000000
# Toplam                       270640        316040  16.775052

# %%
eksiksiz.shape
# Out:
# (1000, 12)

# %%
from scipy.spatial import distance
print(distance.cosine(eksiksiz['item_price'],eksiksiz['quantity'],eksiksiz['transaction_amount']))
print(distance.cosine(eksiksiz['item_price'],eksiksiz['transaction_amount'])) 
print(distance.cosine(eksiksiz['quantity'],eksiksiz['transaction_amount'])) 
print(distance.cosine(eksiksiz['zamli_urun'],eksiksiz['transaction_amount']) )
print( distance.euclidean(eksiksiz['zamli_urun'],eksiksiz['transaction_amount']) )
print( distance.euclidean(eksiksiz['quantity'],eksiksiz['transaction_amount']) )
# Cosine similarity
uzaklık_1_2 = distance.cosine(vector1, vector2) 
uzaklık_1_3 = distance.cosine (vector1, vector3)
print (format(1-uzaklık_1_2, 1-uzaklık_1_3))
# Out:
# 0.18725428465503668
# 0.10565138056438395
# 0.07826289177348589
# 0.10689795822004489
# 9356.667408858775
# 10229.774386563959

# %%
t_kar=tablo.iloc[-1:,-1:]
print(t_kar.sum())
t_zam=tablo.iloc[-1:,-2:-1]
print(t_zam.sum())
t_eski=tablo.iloc[-1:,-3:-2]
print(t_eski.sum())
# Out:
# kar_orani    16.775052
# dtype: float64
# zamli_toplam    316040
# dtype: int64
# transaction_amount    270640
# dtype: int64

# %%
import matplotlib.pyplot as plt
an=50222
bn=85464
cn=48646
plt.bar(["a,b,c"],[an,bn,cn],color=['pink','yellow','blue'])
plt.title("title")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
from scipy.spatial import distance
print(distance.cosine(eksiksiz['item_price'],eksiksiz['quantity'],eksiksiz['transaction_amount']))
# Out:
# 0.11456784358992189

# %%
#total_sales=eksiksiz.groupby(['time_of_sale', 'item_name'])['transaction_amount'].sum().unstack()
#total_sales = eksiksiz.groupby(['time_of_sale', 'item_name']).sum().loc[:,['transaction_amount']]
total_sales = eksiksiz.groupby(['time_of_sale']).sum().loc[:,['transaction_amount','quantity']]
total_sales
# Out:
#               transaction_amount  quantity
# time_of_sale
# Afternoon                  56345      1714
# Evening                    52355      1540
# Midnight                   50725      1575
# Morning                    53730      1574
# Night                      62075      1759

# %%
t1 = eksiksiz.groupby(['item_name']).sum().loc[:
                            ,['transaction_amount','quantity']]
t1
# Out:
#                  transaction_amount  quantity
# item_name
# Aalopuri                      20880      1044
# Cold coffee                   54440      1361
# Frankie                       57500      1150
# Panipuri                      24520      1226
# Sandwich                      65820      1097
# Sugarcane juice               31950      1278
# Vadapav                       20120      1006

# %%
t2 = eksiksiz.groupby(['time_of_sale']).sum().loc[:,
                        ['transaction_amount','quantity']]
t2
# Out:
#               transaction_amount  quantity
# time_of_sale
# Afternoon                  56345      1714
# Evening                    52355      1540
# Midnight                   50725      1575
# Morning                    53730      1574
# Night                      62075      1759
